# %%
from google.colab import drive
drive.mount('/content/drive')

import os
if not os.path.exists('/content/STATUN3106-image-memorability'):
    # !git clone https://github.com/beccangruenberg/STATUN3106-image-memorability.git /content/STATUN3106-image-memorability
else:
    # !git -C /content/STATUN3106-image-memorability pull

# ── SET YOUR DATA PATH HERE ────────────────────────────────
DATA_PATH = "/content/drive/MyDrive/STATUN3106 - Applied Machine Learning/Final Project/STATUN3106_Final_Project/Public/final_submission"
print(f"Data path set to: {DATA_PATH}")

# %pip install -r /content/STATUN3106-image-memorability/requirements.txt
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Already up to date.
# Data path set to: /content/drive/MyDrive/STATUN3106 - Applied Machine Learning/Final Project/STATUN3106_Final_Project/Public/final_submission
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from -r /content/STATUN3106-image-memorability/requirements.txt (line 1)) (1.0.26)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r /content/STATUN3106-image-memorability/requirements.txt (line 3)) (0.25.0+cu128)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r /content/STATUN3106-image-memorability/requirements.txt (line 4)) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r /content/STATUN3106-image-memorability/requirements.txt (line 5)) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from -r /content/STATUN3106-image-memorability/requirements.txt (line 6)) (11.3.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r /content/STATUN3106-image-memorability/requirements.txt (line 7)) (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r /content/STATUN3106-image-memorability/requirements.txt (line 8)) (3.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from timm->-r /content/STATUN3106-image-memorability/requirements.txt (line 1)) (6.0.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm->-r /content/STATUN3106-image-memorability/requirements.txt (line 1)) (1.11.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm->-r /content/STATUN3106-image-memorability/requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/STATUN3106-image-memorability/requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/STATUN3106-image-memorability/requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/STATUN3106-image-memorability/requirements.txt (line 4)) (2026.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r /content/STATUN3106-image-memorability/requirements.txt (line 7)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r /content/STATUN3106-image-memorability/requirements.txt (line 7)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r /content/STATUN3106-image-memorability/requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/STATUN3106-image-memorability/requirements.txt (line 8)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/STATUN3106-image-memorability/requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/STATUN3106-image-memorability/requirements.txt (line 8)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/STATUN3106-image-memorability/requirements.txt (line 8)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/STATUN3106-image-memorability/requirements.txt (line 8)) (26.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/STATUN3106-image-memorability/requirements.txt (line 8)) (3.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->-r /content/STATUN3106-image-memorability/requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm->-r /content/STATUN3106-image-memorability/requirements.txt (line 1)) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm->-r /content/STATUN3106-image-memorability/requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm->-r /content/STATUN3106-image-memorability/requirements.txt (line 1)) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm->-r /content/STATUN3106-image-memorability/requirements.txt (line 1)) (0.24.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r /content/STATUN3106-image-memorability/requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm->-r /content/STATUN3106-image-memorability/requirements.txt (line 1)) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm->-r /content/STATUN3106-image-memorability/requirements.txt (line 1)) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm->-r /content/STATUN3106-image-memorability/requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm->-r /content/STATUN3106-image-memorability/requirements.txt (line 1)) (3.13)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->timm->-r /content/STATUN3106-image-memorability/requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->timm->-r /content/STATUN3106-image-memorability/requirements.txt (line 1)) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->timm->-r /content/STATUN3106-image-memorability/requirements.txt (line 1)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->timm->-r /content/STATUN3106-image-memorability/requirements.txt (line 1)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->timm->-r /content/STATUN3106-image-memorability/requirements.txt (line 1)) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub->timm->-r /content/STATUN3106-image-memorability/requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub->timm->-r /content/STATUN3106-image-memorability/requirements.txt (line 1)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub->timm->-r /content/STATUN3106-image-memorability/requirements.txt (line 1)) (0.1.2)

# %%
import os
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt


df = pd.read_csv(f'{DATA_PATH}/data/image_list_final_with_scores.csv')
print(df.head())
print(f"Dataset size: {len(df)}")

# Sanity check: show a few images with their scores
fig, axes = plt.subplots(1, 3, figsize=(12, 4))
for i, ax in enumerate(axes):
    img = Image.open(f"{DATA_PATH}/data/{df.iloc[i]['image_path']}")
    ax.imshow(img)
    ax.set_title(f"Score: {df.iloc[i]['memorability_score']:.2f}")
    ax.axis('off')
plt.show()
# Out:
#                  image_path  memorability_score
# 0  lamem_final/00000052.jpg            0.710526
# 1  lamem_final/00000116.jpg            0.697674
# 2  lamem_final/00000126.jpg            0.829787
# 3  lamem_final/00000235.jpg            0.864865
# 4  lamem_final/00000256.jpg            0.791667
# Dataset size: 1000

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from sklearn.model_selection import train_test_split

class LaMemDataset(Dataset):
    def __init__(self, df, img_dir, transform=None):
        self.df = df.reset_index(drop=True)
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img = Image.open(f"{self.img_dir}/{self.df.iloc[idx]['image_path']}").convert('RGB')
        score = torch.tensor(self.df.iloc[idx]['memorability_score'], dtype=torch.float32)
        if self.transform:
            img = self.transform(img)
        return img, score

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

img_dir = f"{DATA_PATH}/data/"


train_df, val_df = train_test_split(df, test_size=0.2, random_state=42)
train_loader = DataLoader(LaMemDataset(train_df, img_dir, transform), batch_size=32, shuffle=True)
val_loader = DataLoader(LaMemDataset(val_df, img_dir, transform), batch_size=32)

print(f"Train: {len(train_df)}, Val: {len(val_df)}")
# Out:
# Train: 800, Val: 200

# %%
import torch.nn as nn
import timm

class MemorabilityModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.backbone = timm.create_model('resnet50', pretrained=True, num_classes=0)
        self.regressor = nn.Sequential(
            nn.Linear(2048, 512),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(512, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        features = self.backbone(x)
        return self.regressor(features).squeeze()

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = MemorabilityModel().to(device)
print(f"Running on: {device}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Running on: cuda

# %%
import torch.optim as optim

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

def train_epoch(model, loader):
    model.train()
    total_loss = 0
    for imgs, scores in loader:
        imgs, scores = imgs.to(device), scores.to(device)
        optimizer.zero_grad()
        preds = model(imgs)
        loss = criterion(preds, scores)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(loader)

def val_epoch(model, loader):
    model.eval()
    total_loss = 0
    with torch.no_grad():
        for imgs, scores in loader:
            imgs, scores = imgs.to(device), scores.to(device)
            preds = model(imgs)
            total_loss += criterion(preds, scores).item()
    return total_loss / len(loader)

# Running 20 epochs
for epoch in range(20):
    train_loss = train_epoch(model, train_loader)
    val_loss = val_epoch(model, val_loader)
    print(f"Epoch {epoch+1} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12888/2823576073.py in <cell line: 0>()
#      29 # Running 20 epochs
#      30 for epoch in range(20):
# ---> 31     train_loss = train_epoch(model, train_loader)
#      32     val_loss = val_epoch(model, val_loader)
#      33     print(f"Epoch {epoch+1} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")
#
# /tmp/ipykernel_12888/2823576073.py in train_epoch(model, loader)
#       7     model.train()
#       8     total_loss = 0
# ----> 9     for imgs, scores in loader:
#      10         imgs, scores = imgs.to(device), scores.to(device)
#      11         optimizer.zero_grad()
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     739                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740                 self._reset()  # type: ignore[call-arg]
# --> 741             data = self._next_data()
#     742             self._num_yielded += 1
#     743             if (
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     799     def _next_data(self):
#     800         index = self._next_index()  # may raise StopIteration
# --> 801         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     802         if self._pin_memory:
#     803             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      52                 data = self.dataset.__getitems__(possibly_batched_index)
#      53             else:
# ---> 54                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      55         else:
#      56             data = self.dataset[possibly_batched_index]
#
# /tmp/ipykernel_12888/3262798451.py in __getitem__(self, idx)
#      14
#      15     def __getitem__(self, idx):
# ---> 16         img = Image.open(f"{self.img_dir}/{self.df.iloc[idx]['image_path']}").convert('RGB')
#      17         score = torch.tensor(self.df.iloc[idx]['memorability_score'], dtype=torch.float32)
#      18         if self.transform:
#
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3522         exclusive_fp = True
#    3523
# -> 3524     prefix = fp.read(16)
#    3525
#    3526     preinit()
#
# KeyboardInterrupt:

# %%
from datetime import datetime
timestamp = datetime.now().strftime("%m%d%y_%H%M%S")
torch.save(model.state_dict(), f'{DATA_PATH}/checkpoints/{timestamp}_model_epoch3.pth')
print(f"Saved: {timestamp}_model_epoch3.pth")
